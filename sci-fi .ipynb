# %%
import os
import time
import subprocess
import json

# %%
import wolframalpha
import requests
import webbrowser
import wikipedia
import datetime

# %%
import speech_recognition as sr
import pyttsx3

# %%
print('LOADING YOUR A.I PERSONAL ASSISTANCE JARVIS')
# Out:
# LOADING YOUR A.I PERSONAL ASSISTANCE JARVIS

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice',voices[1].id) # female voice

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if 0 <= hour < 12:
        speak("Hello, Good Morning Ms. Rakshitha")
        print("Hello, Good Morning Ms. Rakshitha")

    elif 12 <= hour < 18:
        speak("Hello, Good Afternoon Ms. Rakshitha")
        print("Hello, Good Afternoon Ms. Rakshitha")

    else:
        speak("It's already night time, better go to sleep.")
        print("It's already night time, better go to sleep.")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("I AM LISTENING.......")
        audio = r.listen(source)

        try:
            print("Recognizing...")
            statement = r.recognize_google(audio, language = 'en-in')
            print(f"User said: {statement}\n")

        except sr.UnknownValueError:
            speak("Sorry, I didn't get that. Please repeat.")
            return "none"
        except sr.RequestError:
            speak("Speech recognition service is down.")
            return "none"

        return statement

# %%
speak("LOADING YOUR PERSONAL A.I ASSISTANT JARVIS")
wishMe()
if __name__ == '__main__':
    
    while True:
        speak("How can i help you?")
        statement = takeCommand().lower()
        if statement == 0:
            continue

        if "good bye" in statement or "ok bye" in statement or "stop" in statement:
            speak("Your personal A.I Assistant JARVIS is shutting down, good bye")
            print("Your personal A.I Assistant JARVIS is shutting down, good bye")
            break

        if 'wikipedia' in statement:
            speak("searching wikipedia......")
            statement = statement.replace("wikipedia"," ")
            results = wikipedia.summary(statement, sentences=3)
            print(results)
            speak(results)

        elif "open youtube" in statement:
            webbrowser.open_new_tab('https://www.youtube.com')
            speak('Youtube is open for you')
            time.sleep(5)

        elif "open google" in statement:
            webbrowser.open_new_tab('https://www.google.com')
            speak('Google is open for you')
            time.sleep(5)

        elif "open gmail" in statement:
            webbrowser.open_new_tab('https://www.gmail.com')
            speak('Gmail is open for you')
            time.sleep(5)

        elif "weather" in statement:
            api_key = os.getenv("OPENWEATHER_API_KEY")
            base_url = 'https://api.openweathermap.org/data/2.5/weather?'
            
            speak('What’s the city name?')
            city_name = takeCommand()

            if not city_name or city_name.lower() == "none":
                speak("Sorry, I didn't catch the city name. Please try again.")
                continue  # goes back to the main loop
            
            complete_url = base_url + "appid=" + api_key + "&q=" + city_name
            response = requests.get(complete_url)
            x = response.json()
            if x['cod'] != "404" :
                y = x["main"]
                current_temperature = y['temp']
                current_humidity = y['humidity']

                z = x['weather']
                weather_description = z[0]['description']
                speak('The temperature in kelvin units is' +str(current_temperature) +'\n Humidity in percentage is' +str(current_humidity) + '\n weather description' +str(weather_description))
                print('The temperature in kelvin units is' +str(current_temperature) +'\n Humidity in percentage is' +str(current_humidity) + '\n weather description' +str(weather_description))

            else:
                speak('city not found')
                print('city not found')

        elif "time" in statement:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f'The time is {strTime}')

        elif "who are you" in statement or "what can you do" in statement:
            speak("I am Jarvis version 1.0 your personal assistant. I am program to minor task likes"
            "opening YouTube, Google, Chrome, Gmail, and stack overflow. predict time, "
            "take a photo, search Wikipedia, predict weather, news from Times of India,"
            "and you can ask me competitional or geographical questions too" )

        elif "who made you" in statement or "who created you" in statement or "who discovered  you" in statement:
            speak("I was built by Ai Robosoft")
            print("I was built by Ai Robosoft")

        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com/login")
            time.sleep(5)

        elif "news" in statement:
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak('Here are some headlines for you from times of india- Happy reading')
            time.sleep(7)

        elif "search" in statement:
            statement = statement.replace('search',' ')
            webbrowser.open_new_tab(statement)
            time.sleep(5)

        elif "ask" in statement:
            speak('I can answer to computational and geographical questions too, just try me!! What do want to ask')
            question = takeCommand()

            app_id = "R2K75H-7ELALHR35X"
            client = wolframalpha.Client("R2K75H-7ELALHR35X")
            res = client.query(question)
            answer = next(res.results).text
            speak(answer)
            print(answer)

        elif "log off" in statement or "sign out" in statement or "shut down" in statement:
            speak('Okay, your pc will shut down in 10 seconds- makesure you have saved and exit all applications')
            subprocess.call(['shutdown','/s', '/t', '10'])

    time.sleep(5)
# Out:
# Hello, Good Afternoon Ms. Rakshitha
# I AM LISTENING.......
# Recognizing...
# I AM LISTENING.......
# Recognizing...
# I AM LISTENING.......
# Recognizing...
# I AM LISTENING.......
# Recognizing...
# User said: open Google
#
# I AM LISTENING.......
# Recognizing...
# User said: thank you for opening Google ok bye
#
# Your personal A.I Assistant JARVIS is shutting down, good bye
